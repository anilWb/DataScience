# %%
import numpy as np

# %%
data = np.loadtxt('populations.txt')

# %%
data
# Out:
# array([[ 1900., 30000.,  4000., 48300.],
#        [ 1901., 47200.,  6100., 48200.],
#        [ 1902., 70200.,  9800., 41500.],
#        [ 1903., 77400., 35200., 38200.],
#        [ 1904., 36300., 59400., 40600.],
#        [ 1905., 20600., 41700., 39800.],
#        [ 1906., 18100., 19000., 38600.],
#        [ 1907., 21400., 13000., 42300.],
#        [ 1908., 22000.,  8300., 44500.],
#        [ 1909., 25400.,  9100., 42100.],
#        [ 1910., 27100.,  7400., 46000.],
#        [ 1911., 40300.,  8000., 46800.],
#        [ 1912., 57000., 12300., 43800.],
#        [ 1913., 76600., 19500., 40900.],
#        [ 1914., 52300., 45700., 39400.],
#        [ 1915., 19500., 51100., 39000.],
#        [ 1916., 11200., 29700., 36700.],
#        [ 1917.,  7600., 15800., 41800.],
#        [ 1918., 14600.,  9700., 43300.],
#        [ 1919., 16200., 10100., 41300.],
#        [ 1920., 24700.,  8600., 47300.]])

# %%
year, hares, lynxes, carrots = data.T
print(year)
# Out:
# [1900. 1901. 1902. 1903. 1904. 1905. 1906. 1907. 1908. 1909. 1910. 1911.
#  1912. 1913. 1914. 1915. 1916. 1917. 1918. 1919. 1920.]

# %%
populations = data[:,1:]
populations
# Out:
# array([[30000.,  4000., 48300.],
#        [47200.,  6100., 48200.],
#        [70200.,  9800., 41500.],
#        [77400., 35200., 38200.],
#        [36300., 59400., 40600.],
#        [20600., 41700., 39800.],
#        [18100., 19000., 38600.],
#        [21400., 13000., 42300.],
#        [22000.,  8300., 44500.],
#        [25400.,  9100., 42100.],
#        [27100.,  7400., 46000.],
#        [40300.,  8000., 46800.],
#        [57000., 12300., 43800.],
#        [76600., 19500., 40900.],
#        [52300., 45700., 39400.],
#        [19500., 51100., 39000.],
#        [11200., 29700., 36700.],
#        [ 7600., 15800., 41800.],
#        [14600.,  9700., 43300.],
#        [16200., 10100., 41300.],
#        [24700.,  8600., 47300.]])

# %%
#sample standard deviation
populations.std(axis=0)
# Out:
# array([20897.90645809, 16254.59153691,  3322.50622558])

# %%
#which spieces has highest population each year
np.argmax(populations, axis=1)
# Out:
# array([2, 2, 0, 0, 1, 1, 2, 2, 2, 2, 2, 2, 0, 0, 0, 1, 2, 2, 2, 2, 2],
#       dtype=int64)

# %%
#avergae population of all of all years
populations.mean(axis=0)
# Out:
# array([34080.95238095, 20166.66666667, 42400.        ])

# %%
# Which year a each species has the largest population
max_years = populations.argsort(axis=0)[0, :]
print (year[max_years])
# Out:
# [1917. 1900. 1916.]

# %%
# Which year any population goes above 50000
above_50k = populations > 50000
print (year[above_50k.any(axis=1)])
# Out:
# [1902. 1903. 1904. 1912. 1913. 1914. 1915.]

# %%
# Top 2 years of lowest populations for each species
lower_2 = populations.argsort(axis=0)[:2]
print (year[lower_2])
# Out:
# [[1917. 1900. 1916.]
#  [1916. 1901. 1903.]]

# %%
# Compare change in hare population and to population of lynxes
hare_grad = np.gradient(hares)
print ("(Hares) vs. Lynxes correlation", np.corrcoef(hare_grad, lynxes)[0, 1])

import matplotlib.pyplot as plt
plt.axes([0.1, 0.1, 0.6, 0.8])
plt.plot(year, hare_grad, label='Hare gradient')
plt.plot(year, lynxes, label='Lynx pop.')
plt.legend(('Hare gradient', 'Lynx pop.'), loc=(1.05, 0.5))
plt.show()
# Out:
# (Hares) vs. Lynxes correlation -0.9179248480315341
